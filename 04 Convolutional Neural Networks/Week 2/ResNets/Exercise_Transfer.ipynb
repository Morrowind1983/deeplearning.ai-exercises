# %%
import numpy as np
import matplotlib.pyplot as plt

from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten
from keras.layers import Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from matplotlib.pyplot import imshow

# %matplotlib inline

import keras.backend as K
K.set_image_data_format('channels_last')
K.set_learning_phase(1)

# %%
from keras.applications.resnet50 import ResNet50

base_model_resnet50 = ResNet50(include_top=False, weights='imagenet')
# Out:
# Using TensorFlow backend.

# %%
X = base_model_resnet50.output

# AVGPOOL
X = AveragePooling2D(pool_size = (2,2), name = 'avg_pool')(X) # 标准输入时 pool_size = (4,4)

# output layer
X = Flatten(name = 'flatten')(X)
predictions = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform())(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-f305c46966de> in <module>()
#       5
#       6 # output layer
# ----> 7 X = Flatten(name = 'flatten')(X)
#       8 predictions = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform())(X)
#
# D:\ProgramData\Anaconda3\lib\site-packages\keras\engine\base_layer.py in __call__(self, inputs, **kwargs)
#     478             if all([s is not None
#     479                     for s in to_list(input_shape)]):
# --> 480                 output_shape = self.compute_output_shape(input_shape)
#     481             else:
#     482                 if isinstance(input_shape, list):
#
# D:\ProgramData\Anaconda3\lib\site-packages\keras\layers\core.py in compute_output_shape(self, input_shape)
#     505             raise ValueError('The shape of the input to "Flatten" '
# ...

# %%
model_resnet50 = Model(inputs=base_model_vgg16.input, outputs=predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-41d058ef3098> in <module>()
# ----> 1 model_resnet50 = Model(inputs=base_model_vgg16.input, outputs=predictions)
#
# NameError: name 'Model' is not defined

# %%
model_resnet50.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c722b3848b08> in <module>()
# ----> 1 model_resnet50.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#
# NameError: name 'model_resnet50' is not defined

# %%
model_resnet50.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# ...

# %%
history = model_resnet50.fit(X_train, Y_train, batch_size=32, epochs=1, validation_split=0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fb3bbd85e4e6> in <module>()
# ----> 1 history = model_resnet50.fit(X_train, Y_train, batch_size=32, epochs=1, validation_split=0.1)
#
# NameError: name 'model_resnet50' is not defined
